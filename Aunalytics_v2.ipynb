# %% [markdown]
# ## Take Home project
# #### Fanbo Meng:   email: fanbomeng23@gmail.com
#
# ### This note book in general consist four parts:
# #### 1. General overview of the data set, some discussion and thinking path during the processing
# #### 2. There are 15 variables in the data, each of them are carefully study and processed, missing data are dealed
# #### 3. Trainging an test the data with 5 different models,  SVM, Logistic regression, Navie bayes, Neuro Networks, Random Forest, accuracy, classification report, AUROC, confusion matrix are checked. For the models, Neuro Networks and Random Forest, grid search  are used to see if better results can be achieved
# #### 4. The summary

# %% [markdown]
# ## Part 1: General Overview

# %% [markdown]
# ### import and checking the basic information about the data

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
import sklearn as sk
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train_data=pd.read_csv('au_train.csv')
test_data=pd.read_csv('au_test.csv')
train_data_back=pd.read_csv('au_train.csv')

# %%
test_data_back=pd.read_csv('au_test.csv')

# %%
train_data.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country   class
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
print('the variables in the data \n {}'.format(list(train_data.keys())))
# Out:
# the variables in the data
#  ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'class']

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# class             32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
test_data.head()
# Out:
#    age   workclass  fnlwgt      education  education-num       marital-status  \
# 0   25     Private  226802           11th              7        Never-married
# 1   38     Private   89814        HS-grad              9   Married-civ-spouse
# 2   28   Local-gov  336951     Assoc-acdm             12   Married-civ-spouse
# 3   44     Private  160323   Some-college             10   Married-civ-spouse
# 4   18           ?  103497   Some-college             10        Never-married
#
#            occupation relationship    race      sex  capital-gain  \
# 0   Machine-op-inspct    Own-child   Black     Male             0
# 1     Farming-fishing      Husband   White     Male             0
# 2     Protective-serv      Husband   White     Male             0
# 3   Machine-op-inspct      Husband   Black     Male          7688
# 4                   ?    Own-child   White   Female             0
#
#    capital-loss  hours-per-week  native-country    class
# 0             0              40   United-States   <=50K.
# 1             0              50   United-States   <=50K.
# 2             0              40   United-States    >50K.
# 3             0              40   United-States    >50K.
# 4             0              30   United-States   <=50K.

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16281 entries, 0 to 16280
# Data columns (total 15 columns):
# age               16281 non-null int64
# workclass         16281 non-null object
# fnlwgt            16281 non-null int64
# education         16281 non-null object
# education-num     16281 non-null int64
# marital-status    16281 non-null object
# occupation        16281 non-null object
# relationship      16281 non-null object
# race              16281 non-null object
# sex               16281 non-null object
# capital-gain      16281 non-null int64
# capital-loss      16281 non-null int64
# hours-per-week    16281 non-null int64
# native-country    16281 non-null object
# class             16281 non-null object
# dtypes: int64(6), object(9)
# memory usage: 1.9+ MB

# %% [markdown]
# ### COMMENT:
# #### the data has no missing value in both training and testing data, but there are fields use ? as input so further check needs

# %% [markdown]
# ### checking all of the unique inputs in the data set

# %%
for name in train_data.keys():
    print('name and the lables {} \n {} '.format(name,train_data[name].unique()))
    print('{}'.format('-'*80))
# Out:
# name and the lables age
#  [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
# --------------------------------------------------------------------------------
# name and the lables workclass
#  [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
# --------------------------------------------------------------------------------
# name and the lables fnlwgt
#  [ 77516  83311 215646 ...  34066  84661 257302]
# --------------------------------------------------------------------------------
# name and the lables education
#  [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
# --------------------------------------------------------------------------------
# name and the lables education-num
#  [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
# --------------------------------------------------------------------------------
# name and the lables marital-status
#  [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
# --------------------------------------------------------------------------------
# name and the lables occupation
#  [' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Sales' ' Craft-repair' ' Transport-moving'
#  ' Farming-fishing' ' Machine-op-inspct' ' Tech-support' ' ?'
#  ' Protective-serv' ' Armed-Forces' ' Priv-house-serv']
# --------------------------------------------------------------------------------
# name and the lables relationship
#  [' Not-in-family' ' Husband' ' Wife' ' Own-child' ' Unmarried'
#  ' Other-relative']
# --------------------------------------------------------------------------------
# name and the lables race
#  [' White' ' Black' ' Asian-Pac-Islander' ' Amer-Indian-Eskimo' ' Other']
# --------------------------------------------------------------------------------
# name and the lables sex
#  [' Male' ' Female']
# --------------------------------------------------------------------------------
# name and the lables capital-gain
#  [ 2174     0 14084  5178  5013  2407 14344 15024  7688 34095  4064  4386
#   7298  1409  3674  1055  3464  2050  2176   594 20051  6849  4101  1111
#   8614  3411  2597 25236  4650  9386  2463  3103 10605  2964  3325  2580
#   3471  4865 99999  6514  1471  2329  2105  2885 25124 10520  2202  2961
#  27828  6767  2228  1506 13550  2635  5556  4787  3781  3137  3818  3942
#    914   401  2829  2977  4934  2062  2354  5455 15020  1424  3273 22040
#   4416  3908 10566   991  4931  1086  7430  6497   114  7896  2346  3418
#   3432  2907  1151  2414  2290 15831 41310  4508  2538  3456  6418  1848
#   3887  5721  9562  1455  2036  1831 11678  2936  2993  7443  6360  1797
#   1173  4687  6723  2009  6097  2653  1639 18481  7978  2387  5060]
# --------------------------------------------------------------------------------
# name and the lables capital-loss
#  [   0 2042 1408 1902 1573 1887 1719 1762 1564 2179 1816 1980 1977 1876
#  1340 2206 1741 1485 2339 2415 1380 1721 2051 2377 1669 2352 1672  653
#  2392 1504 2001 1590 1651 1628 1848 1740 2002 1579 2258 1602  419 2547
#  2174 2205 1726 2444 1138 2238  625  213 1539  880 1668 1092 1594 3004
#  2231 1844  810 2824 2559 2057 1974  974 2149 1825 1735 1258 2129 2603
#  2282  323 4356 2246 1617 1648 2489 3770 1755 3683 2267 2080 2457  155
#  3900 2201 1944 2467 2163 2754 2472 1411]
# --------------------------------------------------------------------------------
# name and the lables hours-per-week
#  [40 13 16 45 50 80 30 35 60 20 52 44 15 25 38 43 55 48 58 32 70  2 22 56
#  41 28 36 24 46 42 12 65  1 10 34 75 98 33 54  8  6 64 19 18 72  5  9 47
#  37 21 26 14  4 59  7 99 53 39 62 57 78 90 66 11 49 84  3 17 68 27 85 31
#  51 77 63 23 87 88 73 89 97 94 29 96 67 82 86 91 81 76 92 61 74 95]
# --------------------------------------------------------------------------------
# name and the lables native-country
#  [' United-States' ' Cuba' ' Jamaica' ' India' ' ?' ' Mexico' ' South'
#  ' Puerto-Rico' ' Honduras' ' England' ' Canada' ' Germany' ' Iran'
#  ' Philippines' ' Italy' ' Poland' ' Columbia' ' Cambodia' ' Thailand'
#  ' Ecuador' ' Laos' ' Taiwan' ' Haiti' ' Portugal' ' Dominican-Republic'
#  ' El-Salvador' ' France' ' Guatemala' ' China' ' Japan' ' Yugoslavia'
#  ' Peru' ' Outlying-US(Guam-USVI-etc)' ' Scotland' ' Trinadad&Tobago'
#  ' Greece' ' Nicaragua' ' Vietnam' ' Hong' ' Ireland' ' Hungary'
#  ' Holand-Netherlands']
# --------------------------------------------------------------------------------
# name and the lables class
#  [' <=50K' ' >50K']
# --------------------------------------------------------------------------------

# %%
test_data['class'].unique()
# Out:
# array([' <=50K.', ' >50K.'], dtype=object)

# %% [markdown]
# ### COMMENT:
# #### 1. '?'  shows up in occupation, nation and workclass, which stand for the class that is not known in general, so check will be needed to see how many data points hold ? value. In the class column, in only two values are there and no missing values in training data, so as in the test data set
#
# #### 2. There are a couple of un-continues varialbes: workclass, education, education number, marital status, occupation, relationship, race, sex,  native country and the label class, the class

# %% [markdown]
# ## Part 2: variable study and modification

# %% [markdown]
# #### the general weight variable fnlwgt, which is the number that the creater of the dataset believes that how many people each input can represent, each entry is a large number, so I will normalize it with MinMax Scale

# %% [markdown]
# #### COMMENT: the weight variable will be considered when necessary

# %%
train_data.fnlwgt=(train_data.fnlwgt-train_data.fnlwgt.min())/(train_data.fnlwgt.max()-train_data.fnlwgt.min())
test_data.fnlwgt=(test_data.fnlwgt-test_data.fnlwgt.min())/(test_data.fnlwgt.max()-test_data.fnlwgt.min())

# %%
plt.hist(train_data.fnlwgt,bins=20)
# Out:
# (array([4.4830e+03, 8.6340e+03, 1.0945e+04, 4.3820e+03, 2.5100e+03,
#         9.8800e+02, 3.4100e+02, 1.3600e+02, 6.4000e+01, 3.8000e+01,
#         1.5000e+01, 5.0000e+00, 5.0000e+00, 5.0000e+00, 2.0000e+00,
#         3.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# ### __Frist__: checking the number of '?' in data variables

# %%
print('percentage of ? in occupation in train data {:.2%}'.format(train_data[train_data.occupation==' ?'].fnlwgt.sum()/train_data.fnlwgt.sum()))
print('percentage of ? in workclass in train data {:.2%}'.format(train_data[train_data.workclass==' ?'].fnlwgt.sum()/train_data.fnlwgt.sum()))
print('percentage of ? in native-country in train data {:.2%}'.format(train_data[train_data['native-country']==' ?'].fnlwgt.sum()/train_data.fnlwgt.sum()))
# Out:
# percentage of ? in occupation in train data 5.62%
# percentage of ? in workclass in train data 5.60%
# percentage of ? in native-country in train data 1.83%

# %% [markdown]
# ### COMMENT:
# #### there seems that not much '?' in the data, in working class and workclass, just on naive look, to me it can be viewed as a sub-small class, but not in native-country. Later by the time of processing this unknown data, further discuss will be shown

# %%
### Check the size of training and orignal training data, in case no mistake is made during the modification
def printsize():
    print(train_data.shape,train_data_back.shape)

# %%
printsize()
# Out:
# (32561, 15) (32561, 15)

# %% [markdown]
# ### Second, deal with the none-continues data

# %% [markdown]
# ### 1. Variable 'class': it can be change to >50K to be 1 and <=50k to be 0   as  two classes, add new column call label_class, as the original one, sometimes used in plotting

# %%
from sklearn.preprocessing import LabelEncoder 
le = LabelEncoder()
le.fit(train_data['class'])
train_data['label_class']=le.transform(train_data['class'])

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.22.1

# %%
train_data.head()
# Out:
#    age          workclass    fnlwgt   education  education-num  \
# 0   39          State-gov  0.044302   Bachelors             13
# 1   50   Self-emp-not-inc  0.048238   Bachelors             13
# 2   38            Private  0.138113     HS-grad              9
# 3   53            Private  0.151068        11th              7
# 4   28            Private  0.221488   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country   class  \
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K
#
#       workclass_copy  label_class
# 0          State-gov            0
# 1   Self-emp-not-inc            0
# 2            Private            0
# 3            Private            0
# 4            Private            0

# %%
le.fit(test_data['class'])
le.transform(test_data['class'])
test_data['label_class']=le.transform(test_data['class'])

# %%
printsize()
# Out:
# (32561, 16) (32561, 15)

# %% [markdown]
# ### 2 The label variable workclass

# %%
train_data.groupby(['workclass','class']).count()['label_class']
# Out:
# workclass          class
#  ?                  <=50K     1645
#                     >50K       191
#  Federal-gov        <=50K      589
#                     >50K       371
#  Local-gov          <=50K     1476
#                     >50K       617
#  Never-worked       <=50K        7
#  Private            <=50K    17733
#                     >50K      4963
#  Self-emp-inc       <=50K      494
#                     >50K       622
#  Self-emp-not-inc   <=50K     1817
#                     >50K       724
#  State-gov          <=50K      945
#                     >50K       353
#  Without-pay        <=50K       14
# Name: label_class, dtype: int64

# %% [markdown]
# #### Check the distribution of the workclass

# %%
sns.set(rc={'figure.figsize':(20.7,4.27)})
sns.countplot(x="workclass",hue='class', data=train_data)

# %% [markdown]
# ### COMMENT:
# #### there are around 5% of unknown data, however this is categrorical data, I want to see if we can infer anything out of it, possibly recover some

# %%
train_data[train_data.workclass==' ?'].head(20)
# Out:
#      age workclass  fnlwgt      education  education-num  \
# 27    54         ?  180211   Some-college             10
# 61    32         ?  293936        7th-8th              4
# 69    25         ?  200681   Some-college             10
# 77    67         ?  212759           10th              6
# 106   17         ?  304873           10th              6
# 128   35         ?  129305        HS-grad              9
# 149   43         ?  174662   Some-college             10
# 154   52         ?  252903        HS-grad              9
# 160   68         ?   38317        1st-4th              2
# 187   53         ?  135105      Bachelors             13
# 201   19         ?  170653        HS-grad              9
# 221   64         ?  187656        1st-4th              2
# 226   60         ?   24215           10th              6
# 243   20         ?  119156   Some-college             10
# 266   19         ?  218956   Some-college             10
# 297   39         ?  157443        Masters             14
# 312   19         ?  860348   Some-college             10
# 326   23         ?  211601      Assoc-voc             11
# 346   67         ?   36135           11th              7
# 347   30         ?  151989      Assoc-voc             11
#
#              marital-status occupation    relationship                 race  \
# 27       Married-civ-spouse          ?         Husband   Asian-Pac-Islander
# 61    Married-spouse-absent          ?   Not-in-family                White
# 69            Never-married          ?       Own-child                White
# 77       Married-civ-spouse          ?         Husband                White
# 106           Never-married          ?       Own-child                White
# 128      Married-civ-spouse          ?         Husband                White
# 149                Divorced          ?   Not-in-family                White
# 154                Divorced          ?   Not-in-family                White
# 160                Divorced          ?   Not-in-family                White
# 187                Divorced          ?   Not-in-family                White
# 201           Never-married          ?       Own-child                White
# 221                Divorced          ?   Not-in-family                White
# 226                Divorced          ?   Not-in-family   Amer-Indian-Eskimo
# 243           Never-married          ?       Own-child                White
# 266           Never-married          ?       Own-child                White
# 297      Married-civ-spouse          ?            Wife   Asian-Pac-Islander
# 312           Never-married          ?       Own-child                Black
# 326           Never-married          ?       Own-child                Black
# 346      Married-civ-spouse          ?         Husband                White
# 347                Divorced          ?       Unmarried                White
#
#          sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 27      Male             0             0              60           South
# 61      Male             0             0              40               ?
# 69      Male             0             0              40   United-States
# 77      Male             0             0               2   United-States
# 106   Female         34095             0              32   United-States
# 128     Male             0             0              40   United-States
# 149   Female             0             0              40   United-States
# 154     Male             0             0              45   United-States
# 160   Female             0             0              20   United-States
# 187   Female             0             0              50   United-States
# 201     Male             0             0              40           Italy
# 221     Male             0             0              40   United-States
# 226   Female             0             0              10   United-States
# 243     Male             0             0              20   United-States
# 266     Male             0             0              24          Canada
# 297   Female          3464             0              40               ?
# 312   Female             0             0              25   United-States
# 326   Female             0             0              15   United-States
# 346     Male             0             0               8   United-States
# 347   Female             0             0              40   United-States
#
#       class  label_class workclass_copy
# 27     >50K            1              ?
# 61    <=50K            0              ?
# 69    <=50K            0              ?
# 77    <=50K            0              ?
# 106   <=50K            0              ?
# 128   <=50K            0              ?
# 149   <=50K            0              ?
# 154    >50K            1              ?
# 160   <=50K            0              ?
# 187   <=50K            0              ?
# 201   <=50K            0              ?
# 221   <=50K            0              ?
# 226   <=50K            0              ?
# 243   <=50K            0              ?
# 266   <=50K            0              ?
# 297   <=50K            0              ?
# 312   <=50K            0              ?
# 326   <=50K            0              ?
# 346   <=50K            0              ?
# 347   <=50K            0              ?

# %% [markdown]
# ### COMMENT:
# #### it seems workclass is unknown, then occupation is also unknown, start checking their relationship

# %%
print('total number of unknown workclass {} \ntotal number of unknown occupation {}'.format(train_data[train_data.workclass==' ?'].shape,train_data[train_data.occupation==' ?'].shape))
# Out:
# total number of unknown workclass (1836, 17)
# total number of unknown occupation (1843, 17)

# %%
train_data[train_data.workclass==' ?'].occupation.unique()
# Out:
# array([' ?'], dtype=object)

# %%
train_data[train_data.occupation==' ?'].workclass.unique()
# Out:
# array([' ?', ' Never-worked'], dtype=object)

# %%
train_data[train_data.workclass==' ?'].groupby('class').count()['occupation']
# Out:
# class
#  <=50K    1645
#  >50K      191
# Name: occupation, dtype: int64

# %% [markdown]
# ### COMMENT:
#
# #### we can see that all of the unknown workclass hold unknow occupation, while all of the unknow occupations have either unknown workclass or as Never-worked
# #### the unknown workclass hold very low >50K percentage, besides the no pay group.
# #### In the below figure, the unknown workclass is relatively concentrage on young age(<30) and elder people(>60).
#
# #### So for now, from my judgement, I will consider these unknow group as a category of unknow, instead of a group that is missed recorded, though there must be ones that are missed recored.

# %%
sns.set(rc={'figure.figsize':(20.7,4.27)})
sns.countplot(x="workclass",hue='class', data=train_data_back)

# %%
workclass_unknown_analysis=train_data[train_data.workclass==' ?']

# %%
plt.title('age distribution of the training data workclass="?" with weights',fontsize=25)
plt.hist(workclass_unknown_analysis[workclass_unknown_analysis.label_class==0].age,weights=workclass_unknown_analysis[workclass_unknown_analysis.label_class==0].fnlwgt,bins=30)
# Out:
# (array([33.05222627, 25.91244006, 18.79479361,  5.99041849, 11.6570958 ,
#          5.54175439,  9.78582673,  6.22224501,  2.61765665,  5.43727197,
#          3.07770609,  3.33840073,  1.91214599,  5.02524076,  1.86419772,
#          3.28071135,  4.70954008,  4.13034732, 10.50887994,  6.11662977,
#          9.66827536,  5.63222858,  3.72271091,  3.48824996,  2.40693348,
#          1.67757569,  0.8331074 ,  0.48301775,  0.05301001,  0.58850803]),
#  array([17.        , 19.43333333, 21.86666667, 24.3       , 26.73333333,
#         29.16666667, 31.6       , 34.03333333, 36.46666667, 38.9       ,
#         41.33333333, 43.76666667, 46.2       , 48.63333333, 51.06666667,
#         53.5       , 55.93333333, 58.36666667, 60.8       , 63.23333333,
#         65.66666667, 68.1       , 70.53333333, 72.96666667, 75.4       ,
#         77.83333333, 80.26666667, 82.7       , 85.13333333, 87.56666667,
#         90.        ]),
#  <a list of 30 Patch objects>)

# %%
printsize()
# Out:
# (32561, 17) (32561, 15)

# %% [markdown]
# ###  DISCUSS:
#
#
#
# ####    For sure the two class Never-worded and Without-pay will be <=50k besides the extrame cases, so these two can merge. still they have very few events, so the unknow class will also goes with it, this call will be call income_L, label as 0
#
# ####  Other classes, besides the Private, they all have very few entries, so based on the plot, number distribution in each classes and a blow plot, which is the ratio of 50K/(total), this workclass is grouped into 3 groups, the ? goes together with the No_work_or_no_pay group, label 0, the private label as 1 and all ther others goes to label 2

# %%
tmp=train_data[train_data.workclass!=' Without-pay']
tmp=tmp[tmp.workclass!=' Never-worked']

# %%
tmp.groupby(['workclass','class']).sum()['fnlwgt']
# Out:
# workclass          class
#  ?                  <=50K     197.529146
#                     >50K       22.218438
#  Federal-gov        <=50K      68.631447
#                     >50K       44.120889
#  Local-gov          <=50K     174.883030
#                     >50K       75.799801
#  Private            <=50K    2186.040867
#                     >50K      595.878685
#  Self-emp-inc       <=50K      51.924530
#                     >50K       72.146808
#  Self-emp-not-inc   <=50K     197.920949
#                     >50K       83.931630
#  State-gov          <=50K     109.838276
#                     >50K       41.656130
# Name: fnlwgt, dtype: float64

# %%
def ratio_plot(df,variable):  
    class_ratio=[]
    indexlist=list(df.groupby([variable,'class']).count()['label_class'].index)
    marry_list=df.groupby([variable,'class']).sum()['fnlwgt']
   # print(marry_list)
 
    i=0
    while i<len(indexlist)-1:
       # if indexlist[i][0]==' Private':
     #   print(marry_list[i],marry_list[i+1])
        class_ratio.append([indexlist[i][0],marry_list[i+1]/(marry_list[i]+marry_list[i+1])])
       # education_class_ratio[education_indexlist[i][0]]=education_list[i+1]/(education_list[i]+education_list[i+1])

        i+=2 
   # print(class_ratio)
    class_ratio=sorted(class_ratio, key = lambda x: x[1])
    x, y = zip(*class_ratio) # unpack a list of pairs into two tuples
    plt.figure(num=None, figsize=(25, 5), dpi=80, facecolor='w', edgecolor='k')
    #print(class_ratio)
    plt.bar(x,y)
    plt.title('ratio of  (Num of >50k) / (total_Num) of different '+variable +' Weighted' ,fontsize=25)

# %%
ratio_plot(tmp,'workclass')

# %%
def data_frame_regroup(df,number_of_groups,group_name_list,general_variable,groupname):
    for group in range(number_of_groups):
        for sub_category in group_name_list[group]:
            df.loc[df[general_variable]==sub_category,general_variable]=groupname[group]

# %%
data_frame_regroup(train_data,3,[[' Never-worked',' Without-pay',' ?'],\
                                 [ ' Private'],[' State-gov', ' Self-emp-not-inc',' Federal-gov',\
                                                ' Local-gov',' Self-emp-inc',]],'workclass',['Pay_L','Pay_M','Pay_H'])

# %%
data_frame_regroup(test_data,3,[[' Never-worked',' Without-pay',' ?'],\
                                 [ ' Private'],[' State-gov', ' Self-emp-not-inc',' Federal-gov',\
                                                ' Local-gov',' Self-emp-inc',]],'workclass',['Pay_L','Pay_M','Pay_H'])

# %%
printsize()
# Out:
# (32561, 16) (32561, 15)

# %% [markdown]
# ### 3. label eduation processing

# %% [markdown]
# ### Discussion
# #### the following two tables are education in different class, the first one is just count without weights, the second one is with weight,  the difference in ratio is small, but there are difference

# %%
train_data.groupby(['education','class']).count()['label_class']
# Out:
# education      class
#  10th           <=50K     871
#                 >50K       62
#  11th           <=50K    1115
#                 >50K       60
#  12th           <=50K     400
#                 >50K       33
#  1st-4th        <=50K     162
#                 >50K        6
#  5th-6th        <=50K     317
#                 >50K       16
#  7th-8th        <=50K     606
#                 >50K       40
#  9th            <=50K     487
#                 >50K       27
#  Assoc-acdm     <=50K     802
#                 >50K      265
#  Assoc-voc      <=50K    1021
#                 >50K      361
#  Bachelors      <=50K    3134
#                 >50K     2221
#  Doctorate      <=50K     107
#                 >50K      306
#  HS-grad        <=50K    8826
#                 >50K     1675
#  Masters        <=50K     764
#                 >50K      959
#  Preschool      <=50K      51
#  Prof-school    <=50K     153
#                 >50K      423
#  Some-college   <=50K    5904
#                 >50K     1387
# Name: label_class, dtype: int64

# %%
train_data.groupby(['education','class'])['fnlwgt'].sum()
# Out:
# education      class
#  10th           <=50K     109.122039
#                 >50K        7.816596
#  11th           <=50K     139.384158
#                 >50K        6.366114
#  12th           <=50K      50.493237
#                 >50K        4.443409
#  1st-4th        <=50K      25.016169
#                 >50K        0.886104
#  5th-6th        <=50K      48.095862
#                 >50K        1.695903
#  7th-8th        <=50K      72.700385
#                 >50K        4.426410
#  9th            <=50K      63.576908
#                 >50K        2.819116
#  Assoc-acdm     <=50K      99.026394
#                 >50K       32.237385
#  Assoc-voc      <=50K     117.559393
#                 >50K       41.673506
#  Bachelors      <=50K     371.288153
#                 >50K      267.967799
#  Doctorate      <=50K      12.130320
#                 >50K       36.791104
#  HS-grad        <=50K    1067.672672
#                 >50K      196.464952
#  Masters        <=50K      85.821105
#                 >50K      110.263277
#  Preschool      <=50K       7.744953
#  Prof-school    <=50K      18.176380
#                 >50K       49.648110
#  Some-college   <=50K     701.516241
#                 >50K      172.252596
# Name: fnlwgt, dtype: float64

# %% [markdown]
# ### COMMENT:
# #### there are 16 class in the education categoray, merge some of the class that close to each other will improve the number of events in each class and improve the accuracy
#
# #### Checking the percentage of >50k in each of the class will help in select if the close classes can merge

# %%
education_class_ratio=[]
education_indexlist=list(train_data.groupby(['education','class']).count()['label_class'].index)
education_list=train_data.groupby(['education','class'])['fnlwgt'].sum()
i=0
while i<len(education_indexlist)-1:
    if education_indexlist[i]==(' Preschool', ' <=50K'):
        i+=1
        continue
    elif education_indexlist[i][0]==education_indexlist[i+1][0]:
        education_class_ratio.append([education_indexlist[i][0],education_list[i+1]/(education_list[i]+education_list[i+1])])
       # education_class_ratio[education_indexlist[i][0]]=education_list[i+1]/(education_list[i]+education_list[i+1])

        i+=2
education_class_ratio.append(['Preschool',0])  
education_class_ratio=sorted(education_class_ratio, key = lambda x: x[1])
education_class_ratio
x, y = zip(*education_class_ratio) # unpack a list of pairs into two tuples
plt.figure(num=None, figsize=(20, 4), dpi=80, facecolor='w', edgecolor='k')
plt.title('ratio of >50K/Totoal in different education categories with weights',fontsize=20)
plt.bar(x,y)
# Out:
# <BarContainer object of 16 artists>

# %%
train_data['education_copy']=train_data.education

# %%
N = 16
Up_50K = list(train_data[train_data.label_class==1].groupby('education').sum()['fnlwgt'])
Up_50K=Up_50K[:-1]+[0.0]+[Up_50K[-1]]
Down_50K = train_data[train_data.label_class==0].groupby('education').sum()['fnlwgt']
#print(Up_50K,Down_50K)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, Down_50K, width)
p2 = plt.bar(ind, Up_50K, width,bottom=Down_50K)

plt.ylabel('counts')
plt.title('education categories in two income classes with Weight',fontsize=15)
plt.xticks(ind, list(train_data.groupby('education').sum()['fnlwgt'].index))
#plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('<50K', '>50K'))

plt.show()

# %%
def two_class_plot(df,groups,variable,wid):
    N = groups
    Up_50K = train_data[train_data.label_class==1].groupby(variable).sum()['fnlwgt']
    Down_50K = train_data[train_data.label_class==0].groupby(variable).sum()['fnlwgt']
   # print(Up_50K,Down_50K)
    ind = np.arange(N)    # the x locations for the groups
    width = 0.35       # the width of the bars: can also be len(x) sequence
    plt.figure(num=None, figsize=(wid,4), dpi=80, facecolor='w', edgecolor='k')
    p1 = plt.bar(ind, Down_50K, width)
    p2 = plt.bar(ind, Up_50K, width,bottom=Down_50K)

    plt.ylabel('counts')
    plt.title( variable+' categories in two income classes with Weight',fontsize=15)
    plt.xticks(ind, list(train_data.groupby(variable).sum()['fnlwgt'].index))

    plt.legend((p1[0], p2[0]), ('<=50K', '>50K'))

    plt.show()

# %% [markdown]
# ### COMMENT:
# #### merge the variables, looking at the above figure, we have from preschool to 12th, they all relatively few years education and hold simiar >=50k/total_# ratio, I called edu_s,
# #### the HS-grad, some-colleague, Assoc-acdm and Assco-voc in a group (I did not find what are the last two stands for, for now, I merge them, later checkes can be preformed) and I call them edu_m,
# #### the last group is Bachelors, Masters, Prof-school, and Doctorate, though the last three in this group, especially the last two have much higher >50k ratio, but the last two are small in number, hard to make them into a stand alone group, I call them edu_h.

# %%
for edu in [' 11th',' 9th',' 7th-8th',' 5th-6th',' 10th',' 1st-4th',' Preschool', ' 12th']:
    train_data.loc[train_data.education==edu,'education']='edu_s'
for edu in [' HS-grad',' Some-college',' Assoc-acdm',' Assoc-voc']:
    train_data.loc[train_data.education==edu,'education']='edu_m'
for edu in [' Bachelors',' Masters',' Prof-school',' Doctorate']:
    train_data.loc[train_data.education==edu,'education']='edu_h'   

for edu in [' 11th',' 9th',' 7th-8th',' 5th-6th',' 10th',' 1st-4th',' Preschool', ' 12th']:
    test_data.loc[test_data.education==edu,'education']='edu_s'
    
for edu in [' HS-grad',' Some-college',' Assoc-acdm',' Assoc-voc']:
    test_data.loc[test_data.education==edu,'education']='edu_m'
for edu in [' Bachelors',' Masters',' Prof-school',' Doctorate']:
    test_data.loc[test_data.education==edu,'education']='edu_h'

# %%
printsize()
# Out:
# (32561, 16) (32561, 15)

# %% [markdown]
# ### comment:
# #### the education column in train and test data are now relabeled into three groups

# %% [markdown]
# ### 4. study education number variable

# %%
sns.countplot(x="education-num",hue='class', data=train_data)

# %% [markdown]
# ### COMMENT:
# #### Education-num variable is very like the number of education years,  which is likely to have a correlation with education varaible. check will need, on the other hand, if use this variable, re-group this variable is also needed. For now, 1--8 one group called edu_number_s,    9--12 called edu_number_m, at last 12--16 called edu_number_h

# %%
for edu in [1,2,3,4,5,6,7,8]:
    train_data.loc[train_data['education-num']==edu,'education-num']='edu_num_L'
for edu in [9,10,11,12]:
    train_data.loc[train_data['education-num']==edu,'education-num']='edu_num_M'  
for edu in [13,14,15,16]:
    train_data.loc[train_data['education-num']==edu,'education-num']='edu_num_H'
    
for edu in [1,2,3,4,5,6,7,8]:
    test_data.loc[test_data['education-num']==edu,'education-num']='edu_num_L'
for edu in [9,10,11,12]:
    test_data.loc[test_data['education-num']==edu,'education-num']='edu_num_M'   
for edu in [13,14,15,16]:
    test_data.loc[test_data['education-num']==edu,'education-num']='edu_num_H'

# %%
sns.set(rc={'figure.figsize':(10,5)})
correction_matrix=train_data[['education-num','education']].corr()
ax=sns.heatmap(correction_matrix,annot=True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (2.0, 0.0)

# %% [markdown]
# ### COMMENT:
# #### in the way I group the two variables, the education and the education-num, they are totally correlated with each other

# %%
sns.pairplot(vars=['education-num','education'] , data=train_data_back,hue='class')

# %% [markdown]
# ### COMMENT:
# #### both of these two variables are not that powerful, so for now I will use education-num, they are more or less directly related

# %% [markdown]
# ### 5 study with marital status

# %%
train_data.groupby(['marital-status','class']).sum()['fnlwgt']
# Out:
# marital-status          class
#  Divorced                <=50K     469.142910
#                          >50K       54.443800
#  Married-AF-spouse       <=50K       1.700596
#                          >50K        1.046754
#  Married-civ-spouse      <=50K     976.495268
#                          >50K      798.124145
#  Married-spouse-absent   <=50K      47.949522
#                          >50K        3.393251
#  Never-married           <=50K    1267.103429
#                          >50K       61.348531
#  Separated               <=50K     126.268069
#                          >50K        8.892625
#  Widowed                 <=50K     100.664575
#                          >50K        8.503274
# Name: fnlwgt, dtype: float64

# %%
two_class_plot(train_data,7,'marital-status',20)

# %%
sns.set(rc={'figure.figsize':(15.7,4.27)})
ax=sns.countplot(x="marital-status",hue='class', data=train_data)
ax.set_title("martial status counting in each category and each sub group with no weight",fontsize=20)
# Out:
# Text(0.5, 1.0, 'martial status counting in each category and each sub group with no weight')

# %% [markdown]
# ### COMMENT:
# #### for the data counting plot with or without weight, in the categorical variables, the difference is small, the weight is from variable fnlwgt

# %%
ratio_plot(train_data,'marital-status')

# %% [markdown]
# ### DISCUSSION
#
#
# #### Merge these groups into Married_N which includes: Married-AF-spouse, Married-civ-spouse,  they are in group 2, and the others besides Never-married are group 1 and Never-married are group 0

# %%
train_data['marital-status'].unique()
# Out:
# array([' Never-married', ' Married-civ-spouse', ' Divorced',
#        ' Married-spouse-absent', ' Separated', ' Married-AF-spouse',
#        ' Widowed'], dtype=object)

# %%
data_frame_regroup(train_data,3,[[' Never-married'],[' Divorced',' Married-spouse-absent',\
                                                     ' Separated',' Widowed'],[' Married-civ-spouse',' Married-AF-spouse']],'marital-status',['Marry_L','Marry_M','Marry_H'])

data_frame_regroup(test_data,3,[[' Never-married'],[' Divorced',' Married-spouse-absent',\
                                                     ' Separated',' Widowed'],[' Married-civ-spouse',' Married-AF-spouse']],'marital-status',['Marry_L','Marry_M','Marry_H'])

# %% [markdown]
# ### 6. study with occupatons

# %%
sns.set(rc={'figure.figsize':(30.7,6.27)})
ax=sns.countplot(x="occupation",hue='class', data=train_data)
ax.set_title("occupation counting in each category and each sub group",fontsize=35)
# Out:
# Text(0.5, 1.0, 'occupation counting in each category and each sub group')

# %%
train_data.occupation.unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %% [markdown]
# #### apparently, occupation is a variable that can affect income, which is the same as commen sence. I will group the occputation into groups

# %%
ratio_plot(train_data,'occupation')

# %%
ax=sns.countplot(x='occupation',data=train_data,color='b',order = train_data['occupation'].value_counts().index)
ax.set_title("occupation counting in each category ",fontsize=35)
# Out:
# Text(0.5, 1.0, 'occupation counting in each category')

# %%
two_class_plot(train_data,15,'occupation',25)

# %% [markdown]
# ### COMMENT:
# #### Occupation is apparently a good variable for classification, I will group them into three groups, from high >50k income ratio to low ones.
# #### Exec-managerial, Prof-speciality, are call occupation_h, labeled 2.  Proective-serv, Tech-support, Sales, Craft-repair, Transport-moving are call occupation_m labeled 1, all the remainings, Adm-clerical, Machine-op-inspct, Farming-fishing, Armed-force, ? Handiers-cleaners, Other-service and Priv-house-serv labeled 0

# %%
for occu in [' Prof-specialty',' Exec-managerial']:
    train_data.loc[train_data['occupation']==occu,'occupation']='occupation_H'
for occu in [' Protective-serv',' Tech-support',' Sales',' Craft-repair',' Transport-moving']:
    train_data.loc[train_data['occupation']==occu,'occupation']='occupation_M'   
for occu in [' Adm-clerical',' Machine-op-inspct',' Farming-fishing',' Armed-Forces',' ?',' Handlers-cleaners',' Other-service',' Priv-house-serv']:
    train_data.loc[train_data['occupation']==occu,'occupation']='occupation_L'

for occu in [' Prof-specialty',' Exec-managerial']:
    test_data.loc[test_data['occupation']==occu,'occupation']='occupation_H'
for occu in [' Protective-serv',' Tech-support',' Sales',' Craft-repair',' Transport-moving']:
    test_data.loc[test_data['occupation']==occu,'occupation']='occupation_M'   
for occu in [' Adm-clerical',' Machine-op-inspct',' Farming-fishing',' Armed-Forces',' ?',' Handlers-cleaners',' Other-service',' Priv-house-serv']:
    test_data.loc[test_data['occupation']==occu,'occupation']='occupation_L'

# %%
printsize()
# Out:
# (32561, 16) (32561, 15)

# %% [markdown]
# ### 7. study of variable relationship

# %%
sns.set(rc={'figure.figsize':(30.7,6.27)})
ax=sns.countplot(x="relationship",hue='class', data=train_data)
ax.set_title("relationship counting in each category and each sub group not weighted",fontsize=35)
# Out:
# Text(0.5, 1.0, 'relationship counting in each category and each sub group not weighted')

# %%
two_class_plot(train_data,6,'relationship',20)

# %% [markdown]
# ### COMMENT:
# #### 3 group still looks like to good grouping to me: one is Husband and Wife, labeled 2,    one is Not-in-family labeled 1, and the remaining are group 0.

# %%
data_frame_regroup(train_data,3,[[' Other-relative',' Unmarried',' Own-child'],\
                                 [' Not-in-family'],[' Husband', ' Wife']],'relationship',['relationship_L','relationship_M','relationship_H'])
data_frame_regroup(test_data,3,[[' Other-relative',' Unmarried',' Own-child'],\
                                 [' Not-in-family'],[' Husband', ' Wife']],'relationship',['relationship_L','relationship_M','relationship_H'])

# %% [markdown]
# ### 8. study of variable race

# %%
two_class_plot(train_data,5,'race',18)

# %%
ratio_plot(train_data,'race')

# %%
train_data.groupby(['race','class']).sum()['fnlwgt']
# Out:
# race                 class
#  Amer-Indian-Eskimo   <=50K      20.053144
#                       >50K        2.873637
#  Asian-Pac-Islander   <=50K      75.323482
#                       >50K       28.868378
#  Black                <=50K     398.857307
#                       >50K       58.848144
#  Other                <=50K      30.935958
#                       >50K        3.083833
#  White                <=50K    2464.154478
#                       >50K      842.078388
# Name: fnlwgt, dtype: float64

# %%
data_frame_regroup(train_data,2,[[' White',' Asian-Pac-Islander'],\
                                 [ ' Black',' Amer-Indian-Eskimo',
       ' Other']],'race',['race_L','race_M'])
data_frame_regroup(test_data,2,[[' White',' Asian-Pac-Islander'],\
                                 [ ' Black',' Amer-Indian-Eskimo',
       ' Other']],'race',['race_L','race_M'])

# %%
two_class_plot(train_data,2,'race',15)

# %% [markdown]
# ### COMMENT:
# #### white race number is too much larger comparied with other group, it is dominent,  the others besides the Asin-Pac-Islander, are all have similar >50k /total ratio, so I tried to group all the remaining into another group and we see that there are some difference in the number of >50K percentage, which make sence

# %% [markdown]
# ### 9. variable sex

# %%
two_class_plot(train_data,2,'sex',12)

# %%
ratio_plot(train_data,'sex')

# %% [markdown]
# ### COMMENT:
# #### this variable is effective, and only two categories in the data set, so there is not much to do with it, I just keep it as it is

# %%
data_frame_regroup(train_data,2,[[' Male'],[' Female']],'sex',['sex_L','sex_M'])
data_frame_regroup(test_data,2,[[' Male'],[' Female']],'sex',['sex_L','sex_M'])

# %% [markdown]
# ### 10. study with native-country variable

# %%
sns.set(rc={'figure.figsize':(20.7,25.27)})
sns.countplot(y='native-country',data=train_data)

# %%
top_20_country_list=list(train_data.groupby(['native-country']).sum()['fnlwgt'].nlargest(20).index)

# %%
(train_data.groupby(['native-country','class']).sum().loc[top_20_country_list,'fnlwgt'])
# Out:
# native-country       class
#  ?                    <=50K      54.333219
#                       >50K       17.339447
#  Canada               <=50K       8.743128
#                       >50K        5.027210
#  China                <=50K       6.103714
#                       >50K        2.390618
#  Columbia             <=50K       8.161224
#                       >50K        0.368272
#  Cuba                 <=50K      11.011455
#                       >50K        4.086549
#  Dominican-Republic   <=50K       8.265602
#                       >50K        0.282448
#  El-Salvador          <=50K      16.589985
#                       >50K        0.839448
#  England              <=50K       7.056726
#                       >50K        3.339843
#  Germany              <=50K      10.906902
#                       >50K        5.565655
#  Guatemala            <=50K      10.511669
#                       >50K        0.479905
#  India                <=50K       6.475807
#                       >50K        4.136253
#  Italy                <=50K       5.459563
#                       >50K        2.939011
#  Jamaica              <=50K       9.640768
#                       >50K        1.354389
#  Japan                <=50K       4.773357
#                       >50K        2.528877
#  Mexico               <=50K     114.654379
#                       >50K        6.502463
#  Philippines          <=50K      13.813604
#                       >50K        6.872316
#  Poland               <=50K       5.632083
#                       >50K        1.361262
#  Puerto-Rico          <=50K      13.025606
#                       >50K        1.704283
#  South                <=50K       6.602765
#                       >50K        1.612108
#  United-States        <=50K    2609.619859
#                       >50K      853.013015
# Name: fnlwgt, dtype: float64

# %% [markdown]
# ### COMMENT(deal with the missing data) :
# #### From the above print out, we see that the missing data '?' has very similar percentge with respect to that of United States. It is around 1/3. As the nation United-States dominent the total population, as we can infer that, even with in the '?' (unknown) data, most of them are from United-States. The missing data is round 1.79% percenate, so I decided to drop it.

# %%
train_data=train_data[train_data['native-country']!=' ?']
train_data.shape
test_data=test_data[test_data['native-country']!=' ?']
train_data.shape
# Out:
# (31978, 16)

# %%
train_data_back=train_data_back[train_data_back['native-country']!=' ?']

# %%
train_data['native-country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %% [markdown]
# ### COMMENT:
# #### the next action is form two groups, United states and others, then check if these two are different in >50K/total numbers, if not, then drop this variable

# %%
train_data.loc[train_data['native-country']!=' United-States','native-country']='country_M'
train_data.loc[train_data['native-country']==' United-States','native-country']='country_L'

# %%
test_data.loc[test_data['native-country']!=' United-States','native-country']='country_M'
test_data.loc[test_data['native-country']==' United-States','native-country']='country_L'

# %%
two_class_plot(train_data,2,'native-country',12)

# %% [markdown]
# ### COMMENT:
# #### the difference between the two group, United States and Others is not very big, to still usable to me

# %% [markdown]
# ### 11. age variable study

# %%
plt.figure(num=None, figsize=(10, 12), dpi=80, facecolor='w', edgecolor='k')
plt.subplot(311)
plt.hist(train_data[train_data.label_class==0].age,weights=train_data[train_data.label_class==0].fnlwgt,bins=15)
plt.title('class <50K age distribution')
plt.subplot(312)
plt.title('class >50K age distribution')
plt.hist(train_data[train_data.label_class==1].age,weights=train_data[train_data.label_class==1].fnlwgt,bins=15)
plt.subplot(313)
plt.title('class total age distribution')
plt.hist(train_data.age,weights=train_data.fnlwgt,bins=15)
# Out:
# (array([390.00086117, 515.58264082, 515.86074422, 527.98735619,
#         480.65456459, 439.46074625, 336.52826367, 197.8368964 ,
#         197.97421931, 125.79754486,  69.85601527,  31.57404477,
#          14.56064438,   5.14095978,   4.5885807 ]),
#  array([17.        , 21.86666667, 26.73333333, 31.6       , 36.46666667,
#         41.33333333, 46.2       , 51.06666667, 55.93333333, 60.8       ,
#         65.66666667, 70.53333333, 75.4       , 80.26666667, 85.13333333,
#         90.        ]),
#  <a list of 15 Patch objects>)

# %% [markdown]
# ### COMMENT:
#
# #### age variable can make a difference based on the fact that the two class group in general have different distribution as shown above. It will be next to determine how to bin it and how many bins and how to bin it, based on the distribution in each class and the total number of events, the largest age is 90 and the smallest is 17
# ####  I decide to use the fellowing bining: [15, 25, 35, 45, 55, 65, 90]

# %%
def bining(df,list_bin,variable,groups):
    for i in range(len(list_bin)):
        df.loc[df[variable]>=list_bin[i],variable]=i
    for i in range(len(list_bin)):
        df.loc[df[variable]==i,variable]=groups[i]

# %%
bining(train_data,[65,55,45,35,25,15],'age',['age6','age5','age4','age3','age2','age1'])

# %%
bining(test_data,[65,55,45,35,25,15],'age',['age6','age5','age4','age3','age2','age1'])

# %%
two_class_plot(train_data,6,'age',15)

# %% [markdown]
# ### 12. Variable captial-loss and capital-gain

# %% [markdown]
# #### The definination of captial loss:  A capital loss is the loss incurred when a capital asset, such as an investment or real estate, decreases in value.

# %% [markdown]
# #### The definiation of capital gain: Capital gain is a rise in the value of a capital asset (investment or real estate) that gives it a higher worth than the purchase price

# %% [markdown]
# ### Comment: the difference of Captial gain and Captial lose will make sence

# %%
plt.xlim(-5000,20000)
plt.hist((train_data['capital-gain']-train_data['capital-loss']),bins=100)
# Out:
# (array([9.0000e+00, 1.4300e+02, 1.2860e+03, 4.4000e+01, 2.7879e+04,
#         1.0600e+02, 2.9200e+02, 3.6300e+02, 3.1200e+02, 1.1500e+02,
#         6.3000e+01, 5.3300e+02, 5.5000e+01, 2.5000e+01, 6.1000e+01,
#         2.0000e+00, 0.0000e+00, 9.2000e+01, 3.4600e+02, 6.0000e+00,
#         0.0000e+00, 2.0000e+00, 0.0000e+00, 3.6000e+01, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 1.5000e+01, 0.0000e+00,
#         3.3000e+01, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 5.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 2.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.5200e+02]),
#  array([-4356.  , -3312.45, -2268.9 , -1225.35,  -181.8 ,   861.75,
#          1905.3 ,  2948.85,  3992.4 ,  5035.95,  6079.5 ,  7123.05,
#          8166.6 ,  9210.15, 10253.7 , 11297.25, 12340.8 , 13384.35,
#         14427.9 , 15471.45, 16515.  , 17558.55, 18602.1 , 19645.65,
#         20689.2 , 21732.75, 22776.3 , 23819.85, 24863.4 , 25906.95,
#         26950.5 , 27994.05, 29037.6 , 30081.15, 31124.7 , 32168.25,
#         33211.8 , 34255.35, 35298.9 , 36342.45, 37386.  , 38429.55,
#         39473.1 , 40516.65, 41560.2 , 42603.75, 43647.3 , 44690.85,
#         45734.4 , 46777.95, 47821.5 , 48865.05, 49908.6 , 50952.15,
#         51995.7 , 53039.25, 54082.8 , 55126.35, 56169.9 , 57213.45,
#         58257.  , 59300.55, 60344.1 , 61387.65, 62431.2 , 63474.75,
#         64518.3 , 65561.85, 66605.4 , 67648.95, 68692.5 , 69736.05,
#         70779.6 , 71823.15, 72866.7 , 73910.25, 74953.8 , 75997.35,
#         77040.9 , 78084.45, 79128.  , 80171.55, 81215.1 , 82258.65,
#         83302.2 , 84345.75, 85389.3 , 86432.85, 87476.4 , 88519.95,
#         89563.5 , 90607.05, 91650.6 , 92694.15, 93737.7 , 94781.25,
#         95824.8 , 96868.35, 97911.9 , 98955.45, 99999.  ]),
#  <a list of 100 Patch objects>)

# %%
train_data['captial_diff']=train_data['capital-gain']-train_data['capital-loss']

# %%
test_data['captial_diff']=test_data['capital-gain']-test_data['capital-loss']

# %%
tmp=train_data[train_data.captial_diff!=0]
plt.hist([tmp[tmp.label_class==0].captial_diff,tmp[tmp.label_class==1].captial_diff],100, density=True, histtype='bar',label=['<=50K','>50K']\
         , stacked=True,weights=[tmp[tmp.label_class==0]\
.fnlwgt,tmp[tmp.label_class==1].fnlwgt])
plt.legend(prop={'size': 20})
plt.xlim(-5000,30000)
plt.title('Capital difference, ZERO values are not included for visualization',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Capital difference, ZERO values are not included for visualization')

# %%
tmp2=train_data[train_data.captial_diff!=0]
tmp2.captial_diff=abs(tmp2.captial_diff)
plt.hist([tmp2[tmp2.label_class==0].captial_diff,tmp2[tmp2.label_class==1].captial_diff],100, density=True, histtype='bar',label=['<=50K','>50K']\
         , stacked=True,weights=[tmp2[tmp2.label_class==0]\
.fnlwgt,tmp2[tmp2.label_class==1].fnlwgt])
plt.legend(prop={'size': 20})
plt.xlim(-5000,30000)
plt.title('abs(Capital difference), ZERO values are not included for visualization',fontsize=20)
# Out:
# /anaconda3/envs/tensorflow_env/lib/python3.6/site-packages/pandas/core/generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# Text(0.5, 1.0, 'abs(Capital difference), ZERO values are not included for visualization')

# %%
tmp=train_data[train_data.captial_diff==0]
plt.hist([tmp[tmp.label_class==0].captial_diff,tmp[tmp.label_class==1].captial_diff],350, density=True, histtype='bar',label=['<=50K','>50K']\
         , stacked=True,weights=[tmp[tmp.label_class==0]\
.fnlwgt,tmp[tmp.label_class==1].fnlwgt])
plt.legend(prop={'size': 20})
#plt.xlim(-5000,30000)
plt.title('Weighted Capital difference at ZERO',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Weighted Capital difference at ZERO')

# %%
print('The numbef of Zero items in capitial differnce ={}\nThe none Zeros ones= {}'.format(train_data[train_data.captial_diff==0].count()['label_class'],train_data[train_data.captial_diff!=0].count()['label_class']))
# Out:
# The numbef of Zero items in capitial differnce =27837
# The none Zeros ones= 4141

# %%
train_data.captial_diff.describe()
# Out:
# count    31978.000000
# mean       977.621271
# std       7322.256154
# min      -4356.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      99999.000000
# Name: captial_diff, dtype: float64

# %% [markdown]
# ### COMMENT:
# #### The trand is clear,  the groups that are higher and lower ends hold larger percentage of >50K values.  the larger the capital difference the higher percentage of the >50K class.
# #### The absolute plot of this variable is also checked, it does not make much difference, considering the vaue at zero is huge
# #### So from the plot, I group the values in to two groups, group 0 with range[-5000,5000] and the second group [5000, 100000]

# %%
train_data.loc[train_data.captial_diff<=5000,'captial_diff']=0
train_data.loc[train_data.captial_diff>5000,'captial_diff']=1
train_data.loc[train_data.captial_diff==0,'captial_diff']='capital_L'
train_data.loc[train_data.captial_diff==1,'captial_diff']='capital_M'

# %%
test_data.loc[test_data.captial_diff<=5000,'captial_diff']=0
test_data.loc[test_data.captial_diff>5000,'captial_diff']=1

test_data.loc[test_data.captial_diff==0,'captial_diff']='capital_L'
test_data.loc[test_data.captial_diff==1,'captial_diff']='capital_M'

# %%
two_class_plot(train_data,2,'captial_diff',12)

# %% [markdown]
# ### COMMENT:
# #### the new distribution of captial difference after the regourp

# %% [markdown]
# ### 13. Variable hours-per-week study

# %%
plt.hist([train_data[train_data.label_class==0]['hours-per-week'],train_data[train_data.label_class==1]['hours-per-week']],25, density=True, histtype='bar',label=['<=50K','>50K']\
         , stacked=True,weights=[train_data[train_data.label_class==0]\
.fnlwgt,train_data[train_data.label_class==1].fnlwgt])
plt.legend(prop={'size': 20})
plt.xlim(0,100)
plt.title('Weighted hours-per-week difference',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Weighted hours-per-week difference')

# %%
tmp=train_data[train_data['hours-per-week']!=40]
plt.hist([tmp[tmp.label_class==0]['hours-per-week'],tmp[tmp.label_class==1]['hours-per-week']],25, density=True, histtype='bar',label=['<=50K','>50K']\
         , stacked=True,weights=[tmp[tmp.label_class==0]\
.fnlwgt,tmp[tmp.label_class==1].fnlwgt])
plt.legend(prop={'size': 20})
plt.xlim(0,100)
plt.title('Weighted hours-per-week without hours=40',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Weighted hours-per-week without hours=40')

# %% [markdown]
# ### COMMENT:
# #### from the working time distribution above, two groups look resonable to me, group 0 hours<40, group 1 hours>=40

# %%
train_data.loc[train_data['hours-per-week']<40,'hours-per-week']=0
train_data.loc[train_data['hours-per-week']>=40,'hours-per-week']=1
train_data.loc[train_data['hours-per-week']==0,'hours-per-week']='work_hours_L'
train_data.loc[train_data['hours-per-week']==1,'hours-per-week']='work_hours_M'

# %%
test_data.loc[test_data['hours-per-week']<40,'hours-per-week']=0
test_data.loc[test_data['hours-per-week']>=40,'hours-per-week']=1
test_data.loc[test_data['hours-per-week']==0,'hours-per-week']='work_hours_L'
test_data.loc[test_data['hours-per-week']==1,'hours-per-week']='work_hours_M'

# %%
printsize()
# Out:
# (31978, 17) (31978, 15)

# %%
two_class_plot(train_data,2,'hours-per-week',12)

# %%
train_data.head()
# Out:
#     age workclass    fnlwgt education education-num marital-status  \
# 0  age3     Pay_H  0.044302     edu_h     edu_num_H        Marry_L
# 1  age4     Pay_H  0.048238     edu_h     edu_num_H        Marry_H
# 2  age3     Pay_M  0.138113     edu_m     edu_num_M        Marry_M
# 3  age4     Pay_M  0.151068     edu_s     edu_num_L        Marry_H
# 4  age2     Pay_M  0.221488     edu_h     edu_num_H        Marry_H
#
#      occupation    relationship    race    sex  capital-gain  capital-loss  \
# 0  occupation_L  relationship_M  race_L  sex_L          2174             0
# 1  occupation_H  relationship_H  race_L  sex_L             0             0
# 2  occupation_L  relationship_M  race_L  sex_L             0             0
# 3  occupation_L  relationship_H  race_M  sex_L             0             0
# 4  occupation_H  relationship_H  race_M  sex_M             0             0
#
#   hours-per-week native-country   class  label_class captial_diff
# 0   work_hours_M      country_L   <=50K            0    capital_L
# 1   work_hours_L      country_L   <=50K            0    capital_L
# 2   work_hours_M      country_L   <=50K            0    capital_L
# 3   work_hours_M      country_L   <=50K            0    capital_L
# 4   work_hours_M      country_M   <=50K            0    capital_L

# %%
test_data.head()
# Out:
#     age workclass    fnlwgt education education-num marital-status  \
# 0  age2     Pay_M  0.144430     edu_s     edu_num_L        Marry_L
# 1  age3     Pay_M  0.051677     edu_m     edu_num_M        Marry_H
# 2  age2     Pay_H  0.219011     edu_m     edu_num_M        Marry_H
# 3  age3     Pay_M  0.099418     edu_m     edu_num_M        Marry_H
# 4  age1     Pay_L  0.060942     edu_m     edu_num_M        Marry_L
#
#      occupation    relationship    race    sex  capital-gain  capital-loss  \
# 0  occupation_L  relationship_L  race_M  sex_L             0             0
# 1  occupation_L  relationship_H  race_L  sex_L             0             0
# 2  occupation_M  relationship_H  race_L  sex_L             0             0
# 3  occupation_L  relationship_H  race_M  sex_L          7688             0
# 4  occupation_L  relationship_L  race_L  sex_M             0             0
#
#   hours-per-week native-country    class  label_class captial_diff
# 0   work_hours_M      country_L   <=50K.            0    capital_L
# 1   work_hours_M      country_L   <=50K.            0    capital_L
# 2   work_hours_M      country_L    >50K.            1    capital_L
# 3   work_hours_M      country_L    >50K.            1    capital_M
# 4   work_hours_L      country_L   <=50K.            0    capital_L

# %%
tmp1=train_data
tmp2=test_data

# %%
test_data.shape
# Out:
# (16007, 13)

# %%
train_data.drop(['capital-gain', 'capital-loss','class','education'], axis=1,inplace=True)
test_data.drop(['capital-gain', 'capital-loss','class','education'], axis=1,inplace=True)

# %%
train_data.head()
# Out:
#     age workclass    fnlwgt education-num marital-status    occupation  \
# 0  age3     Pay_H  0.044302     edu_num_H        Marry_L  occupation_L
# 1  age4     Pay_H  0.048238     edu_num_H        Marry_H  occupation_H
# 2  age3     Pay_M  0.138113     edu_num_M        Marry_M  occupation_L
# 3  age4     Pay_M  0.151068     edu_num_L        Marry_H  occupation_L
# 4  age2     Pay_M  0.221488     edu_num_H        Marry_H  occupation_H
#
#      relationship    race    sex hours-per-week native-country captial_diff  \
# 0  relationship_M  race_L  sex_L   work_hours_M      country_L    capital_L
# 1  relationship_H  race_L  sex_L   work_hours_L      country_L    capital_L
# 2  relationship_M  race_L  sex_L   work_hours_M      country_L    capital_L
# 3  relationship_H  race_M  sex_L   work_hours_M      country_L    capital_L
# 4  relationship_H  race_M  sex_M   work_hours_M      country_M    capital_L
#
#    label_class
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
test_data.head()
# Out:
#     age workclass    fnlwgt education-num marital-status    occupation  \
# 0  age2     Pay_M  0.144430     edu_num_L        Marry_L  occupation_L
# 1  age3     Pay_M  0.051677     edu_num_M        Marry_H  occupation_L
# 2  age2     Pay_H  0.219011     edu_num_M        Marry_H  occupation_M
# 3  age3     Pay_M  0.099418     edu_num_M        Marry_H  occupation_L
# 4  age1     Pay_L  0.060942     edu_num_M        Marry_L  occupation_L
#
#      relationship    race    sex hours-per-week native-country captial_diff  \
# 0  relationship_L  race_M  sex_L   work_hours_M      country_L    capital_L
# 1  relationship_H  race_L  sex_L   work_hours_M      country_L    capital_L
# 2  relationship_H  race_L  sex_L   work_hours_M      country_L    capital_L
# 3  relationship_H  race_M  sex_L   work_hours_M      country_L    capital_M
# 4  relationship_L  race_L  sex_M   work_hours_L      country_L    capital_L
#
#    label_class
# 0            0
# 1            0
# 2            1
# 3            1
# 4            0

# %%
train_data.keys()
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'hours-per-week',
#        'native-country', 'label_class', 'captial_diff'],
#       dtype='object')

# %%
train_data=train_data[['age', 'workclass', 'fnlwgt', 'education-num',
       'marital-status', 'occupation', 'relationship', 'race', 'sex',
       'hours-per-week', 'native-country', 'captial_diff','label_class']]

# %%
test_data=test_data[['age', 'workclass', 'fnlwgt', 'education-num',
       'marital-status', 'occupation', 'relationship', 'race', 'sex',
       'hours-per-week', 'native-country', 'captial_diff','label_class']]

# %% [markdown]
# ## Part 3. Model training, testing and performance check

# %% [markdown]
# ### Different models will be used, the SVM, Random forest, logistic regression, Naive bayes, Boosted Decision Tree

# %% [markdown]
# ### 1. SVM classifer

# %%
from sklearn.metrics import confusion_matrix

# %%
from sklearn.metrics import roc_curve, auc

# %% [markdown]
# ### Discusssion(imbalance in training and testing data):
# #### The training and testing data are highly imblanced with respect to the two classes, during the grouping state, the >50K class with less events is paid more attention. The following reshaped training will be a new group, reduced the <=50K in number and seek to come to a balance with the other group

# %%
train_data.groupby('label_class').count()['age']
# Out:
# label_class
# 0    24283
# 1     7695
# Name: age, dtype: int64

# %%
train_data_split_class0=train_data[train_data.label_class==0].sample(n=10000, random_state=1)

# %%
train_data_split_class1=train_data[train_data.label_class==1]
train_split= [train_data_split_class0,train_data_split_class1]
train_split = pd.concat(train_split)

# %%
test_data.groupby('label_class').count()['age']
# Out:
# label_class
# 0    12235
# 1     3772
# Name: age, dtype: int64

# %%
test_data_split_class0=test_data[test_data.label_class==0].sample(n=3772, random_state=1)
test_data_split_class1=test_data[test_data.label_class==1]
test_split= [test_data_split_class0,test_data_split_class1]
test_split = pd.concat(test_split)

# %% [markdown]
# ### DISCUSSION
#
# ### change label data into one hot vector
# #### As weight variable is used usually in the fit separately, split this varaible with the others

# %%
train_split_weight=train_split.fnlwgt
test_split_weight=test_split.fnlwgt

train_split_label=train_split.label_class
test_split_label=test_split.label_class


train_split_org=train_split
test_split_org=test_split

test_split.drop(['fnlwgt','label_class'],axis=1,inplace=True)
train_split.drop(['fnlwgt','label_class'],axis=1,inplace=True)

train_split=pd.get_dummies(train_split)
test_split=pd.get_dummies(test_split)



train_split['label_class']=train_split_label
test_split['label_class']=test_split_label

# %%
train_split.head()
# Out:
#        age_age1  age_age2  age_age3  age_age4  age_age5  age_age6  \
# 21259         0         1         0         0         0         0
# 27494         0         1         0         0         0         0
# 13699         1         0         0         0         0         0
# 3973          1         0         0         0         0         0
# 243           1         0         0         0         0         0
#
#        workclass_Pay_H  workclass_Pay_L  workclass_Pay_M  \
# 21259                0                0                1
# 27494                0                0                1
# 13699                0                0                1
# 3973                 0                0                1
# 243                  0                1                0
#
#        education-num_edu_num_H  ...  race_race_M  sex_sex_L  sex_sex_M  \
# 21259                        1  ...            0          0          1
# 27494                        1  ...            0          1          0
# 13699                        0  ...            0          1          0
# 3973                         0  ...            1          0          1
# 243                          0  ...            0          1          0
#
#        hours-per-week_work_hours_L  hours-per-week_work_hours_M  \
# 21259                            0                            1
# 27494                            0                            1
# 13699                            0                            1
# 3973                             1                            0
# 243                              1                            0
#
#        native-country_country_L  native-country_country_M  \
# 21259                         1                         0
# 27494                         1                         0
# 13699                         0                         1
# 3973                          0                         1
# 243                           1                         0
#
#        captial_diff_capital_L  captial_diff_capital_M  label_class
# 21259                       1                       0            0
# 27494                       1                       0            0
# 13699                       1                       0            0
# 3973                        1                       0            0
# 243                         1                       0            0
#
# [5 rows x 32 columns]

# %%
test_split.head()
# Out:
#        age_age1  age_age2  age_age3  age_age4  age_age5  age_age6  \
# 3702          0         1         0         0         0         0
# 10657         0         1         0         0         0         0
# 12320         0         1         0         0         0         0
# 10170         0         1         0         0         0         0
# 3111          1         0         0         0         0         0
#
#        workclass_Pay_H  workclass_Pay_L  workclass_Pay_M  \
# 3702                 0                0                1
# 10657                0                0                1
# 12320                0                0                1
# 10170                0                0                1
# 3111                 0                0                1
#
#        education-num_edu_num_H  ...  race_race_M  sex_sex_L  sex_sex_M  \
# 3702                         0  ...            0          0          1
# 10657                        0  ...            0          0          1
# 12320                        0  ...            0          0          1
# 10170                        0  ...            0          0          1
# 3111                         1  ...            0          1          0
#
#        hours-per-week_work_hours_L  hours-per-week_work_hours_M  \
# 3702                             1                            0
# 10657                            1                            0
# 12320                            1                            0
# 10170                            0                            1
# 3111                             0                            1
#
#        native-country_country_L  native-country_country_M  \
# 3702                          1                         0
# 10657                         1                         0
# 12320                         1                         0
# 10170                         1                         0
# 3111                          1                         0
#
#        captial_diff_capital_L  captial_diff_capital_M  label_class
# 3702                        1                       0            0
# 10657                       1                       0            0
# 12320                       1                       0            0
# 10170                       1                       0            0
# 3111                        1                       0            0
#
# [5 rows x 32 columns]

# %%
from sklearn.svm import SVC
clf = SVC(gamma='auto')
score=clf.fit(train_split.iloc[:,:-1], train_split.label_class,sample_weight=train_split_weight).decision_function(test_split.iloc[:,:-1])

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
accuracy=dict()

# %%
accuracy['SVM']=clf.score(test_split.iloc[:,:-1],test_split.label_class,sample_weight=test_split_weight)
fpr['SVM'], tpr['SVM'], _ = roc_curve(test_split.label_class, score)
roc_auc['SVM'] = auc(fpr['SVM'], tpr['SVM'])

# %%
print('the accucary of the SVM model without grid search is {:.2%}'.format(accuracy['SVM']))
# Out:
# the accucary of the SVM model without grid search is 81.76%

# %% [markdown]
# ### SVM accuracy on test data is 81.76%

# %%
from sklearn.metrics import plot_confusion_matrix

# %%
def confusion_matrix_plot(Models,mathod_name):
    titles_options = [(mathod_name+" Confusion matrix, without normalization", None),
                      (mathod_name+" Normalized confusion matrix", 'true')]
    for title, normalize in titles_options:
        disp = plot_confusion_matrix(Models,test_split.iloc[:,:-1],test_split.label_class,
                                 display_labels=['<=50K','>50K'],
                                 cmap=plt.cm.Blues,
                                 normalize=normalize)
        disp.ax_.set_title(title)

        print(title)
        print(disp.confusion_matrix)

# %%
confusion_matrix_plot(clf,'SVM')
# Out:
# SVM Confusion matrix, without normalization
# [[2946  826]
#  [ 592 3180]]
# SVM Normalized confusion matrix
# [[0.78101803 0.21898197]
#  [0.15694592 0.84305408]]

# %%
from sklearn.metrics import classification_report
target_names = ['class 0', 'class 1']
print(classification_report(test_split.label_class,clf.predict(test_split.iloc[:,:-1]), target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.83      0.78      0.81      3772
#      class 1       0.79      0.84      0.82      3772
#
#     accuracy                           0.81      7544
#    macro avg       0.81      0.81      0.81      7544
# weighted avg       0.81      0.81      0.81      7544

# %%
def AUROC_plot(method):
    plt.figure()
    lw = 2
    plt.plot(fpr[method], tpr[method], color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[method])
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic of method ' +method,fontsize=20)
    plt.legend(loc="lower right",prop={'size': 20})
    plt.show()

# %%
AUROC_plot('SVM')

# %% [markdown]
# ### COMMENT:
# #### the SVM method in general behaves ok, with the adjustment of training data different class ratio,  a balanced precesion, and recall score is achieved, around 82%.  Over all, the SVM is ok from the value of AUROC, F1 score

# %% [markdown]
# ### 2. Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf_logistic = LogisticRegression(random_state=0).fit(train_split.iloc[:,:-1], train_split.label_class,sample_weight=train_split_weight)
clf_logistic.score(test_split.iloc[:,:-1],test_split.label_class,sample_weight=test_split_weight)
# Out:
# 0.8150899492513166

# %%
def save_acc_and_roc(models,method):
    accuracy[method]=models.score(test_split.iloc[:,:-1],test_split.label_class,sample_weight=test_split_weight)
    fpr[method], tpr[method], _ = roc_curve(test_split.label_class, score)
    roc_auc[method] = auc(fpr[method], tpr[method])

# %%
save_acc_and_roc(clf_logistic,'Logistic')

# %%
print('the accucary of the Logistic regression model without grid search is {:.2%}'.format(accuracy['Logistic']))
# Out:
# the accucary of the Logistic regression model without grid search is 81.51%

# %% [markdown]
# ###  Logistic regression accuracy on test data is 81.5%

# %%
confusion_matrix_plot(clf_logistic,'Logistic')
# Out:
# Logistic Confusion matrix, without normalization
# [[3147  625]
#  [ 808 2964]]
# Logistic Normalized confusion matrix
# [[0.83430541 0.16569459]
#  [0.21420997 0.78579003]]

# %%
print(classification_report(test_split.label_class,clf_logistic.predict(test_split.iloc[:,:-1]), target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.80      0.83      0.81      3772
#      class 1       0.83      0.79      0.81      3772
#
#     accuracy                           0.81      7544
#    macro avg       0.81      0.81      0.81      7544
# weighted avg       0.81      0.81      0.81      7544

# %%
AUROC_plot('Logistic')

# %% [markdown]
# ### COMMENT:
# #### Logistic regression behave very similar to SVM(without tuning), a bit less in f1 score

# %% [markdown]
# ### 3. Naive bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()
gnb.fit(train_split.iloc[:,:-1], train_split.label_class,sample_weight=train_split_weight)
print('the accucary of the Naive bayes model  {:.2%}'.format(gnb.score(test_split.iloc[:,:-1],test_split.label_class,sample_weight=test_split_weight)))
# Out:
# the accucary of the Naive bayes model  81.03%

# %%
save_acc_and_roc(gnb,'NB')

# %%
confusion_matrix_plot(gnb,'NB')
# Out:
# NB Confusion matrix, without normalization
# [[3006  766]
#  [ 715 3057]]
# NB Normalized confusion matrix
# [[0.79692471 0.20307529]
#  [0.18955461 0.81044539]]

# %%
print(classification_report(test_split.label_class,gnb.predict(test_split.iloc[:,:-1]), target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.81      0.80      0.80      3772
#      class 1       0.80      0.81      0.81      3772
#
#     accuracy                           0.80      7544
#    macro avg       0.80      0.80      0.80      7544
# weighted avg       0.80      0.80      0.80      7544

# %%
AUROC_plot('NB')

# %% [markdown]
# #### COMMENT:
# #### Naive bayes has similar behaviour with respect the other two methods

# %% [markdown]
# ### 4. Neuro Network

# %%
from sklearn.neural_network import MLPClassifier
NN = MLPClassifier(solver='lbfgs', alpha=1e-5,
                     hidden_layer_sizes=(10,3), random_state=1,max_iter=3000)
NN.fit(train_split.iloc[:,:-1], train_split.label_class)
print('the accucary of the Neuro Network  {:.2%}'.format(NN.score(test_split.iloc[:,:-1],test_split.label_class)))
# Out:
# the accucary of the Neuro Network  80.98%

# %%
save_acc_and_roc(NN,'NN')

# %%
confusion_matrix_plot(NN,'NN')
# Out:
# NN Confusion matrix, without normalization
# [[3143  629]
#  [ 806 2966]]
# NN Normalized confusion matrix
# [[0.83324496 0.16675504]
#  [0.21367975 0.78632025]]

# %%
print(classification_report(test_split.label_class,NN.predict(test_split.iloc[:,:-1]), target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.80      0.83      0.81      3772
#      class 1       0.83      0.79      0.81      3772
#
#     accuracy                           0.81      7544
#    macro avg       0.81      0.81      0.81      7544
# weighted avg       0.81      0.81      0.81      7544

# %% [markdown]
# ### COMMENT:
# #### the untuned Neuro network hold similar behaviour with respect to previous methods

# %% [markdown]
# ### DISCUSSION(grid search)
# #### A not complete grid search on the NN

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = [{'solver':['lbfgs','adam'],'hidden_layer_sizes':[(5,2),(8,2),(10,2),(5,3),(8,3),(12,3),(7,4)],}]
grid = GridSearchCV(MLPClassifier(alpha=1e-5,max_iter=3000), param_grid, refit=True, verbose=4)
grid.fit(train_data_split.iloc[:,:-1], train_data_split.label_class)
# Out:
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV] hidden_layer_sizes=(5, 2), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(5, 2), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(5, 2), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(5, 2), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(5, 2), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(5, 2), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(5, 2), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(5, 2), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(5, 2), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(5, 2), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(5, 2), solver=adam ..........................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [CV]  hidden_layer_sizes=(5, 2), solver=adam, score=1.000, total=   0.4s
# [CV] hidden_layer_sizes=(5, 2), solver=adam ..........................
# [CV]  hidden_layer_sizes=(5, 2), solver=adam, score=1.000, total=   0.3s
# [CV] hidden_layer_sizes=(5, 2), solver=adam ..........................
# [CV]  hidden_layer_sizes=(5, 2), solver=adam, score=1.000, total=   0.4s
# [CV] hidden_layer_sizes=(5, 2), solver=adam ..........................
# [CV]  hidden_layer_sizes=(5, 2), solver=adam, score=1.000, total=   0.8s
# [CV] hidden_layer_sizes=(5, 2), solver=adam ..........................
# [CV]  hidden_layer_sizes=(5, 2), solver=adam, score=1.000, total=   0.5s
# [CV] hidden_layer_sizes=(8, 2), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(8, 2), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(8, 2), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(8, 2), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(8, 2), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(8, 2), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(8, 2), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(8, 2), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(8, 2), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(8, 2), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(8, 2), solver=adam ..........................
# [CV]  hidden_layer_sizes=(8, 2), solver=adam, score=1.000, total=   0.4s
# [CV] hidden_layer_sizes=(8, 2), solver=adam ..........................
# [CV]  hidden_layer_sizes=(8, 2), solver=adam, score=1.000, total=   2.4s
# [CV] hidden_layer_sizes=(8, 2), solver=adam ..........................
# [CV]  hidden_layer_sizes=(8, 2), solver=adam, score=1.000, total=   0.3s
# [CV] hidden_layer_sizes=(8, 2), solver=adam ..........................
# [CV]  hidden_layer_sizes=(8, 2), solver=adam, score=1.000, total=   0.3s
# [CV] hidden_layer_sizes=(8, 2), solver=adam ..........................
# [CV]  hidden_layer_sizes=(8, 2), solver=adam, score=1.000, total=   0.3s
# [CV] hidden_layer_sizes=(10, 2), solver=lbfgs ........................
# [CV]  hidden_layer_sizes=(10, 2), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(10, 2), solver=lbfgs ........................
# [CV]  hidden_layer_sizes=(10, 2), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(10, 2), solver=lbfgs ........................
# [CV]  hidden_layer_sizes=(10, 2), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(10, 2), solver=lbfgs ........................
# [CV]  hidden_layer_sizes=(10, 2), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(10, 2), solver=lbfgs ........................
# [CV]  hidden_layer_sizes=(10, 2), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(10, 2), solver=adam .........................
# [CV]  hidden_layer_sizes=(10, 2), solver=adam, score=1.000, total=   0.4s
# [CV] hidden_layer_sizes=(10, 2), solver=adam .........................
# [CV]  hidden_layer_sizes=(10, 2), solver=adam, score=1.000, total=   0.5s
# [CV] hidden_layer_sizes=(10, 2), solver=adam .........................
# [CV]  hidden_layer_sizes=(10, 2), solver=adam, score=1.000, total=   0.4s
# [CV] hidden_layer_sizes=(10, 2), solver=adam .........................
# [CV]  hidden_layer_sizes=(10, 2), solver=adam, score=1.000, total=   3.3s
# [CV] hidden_layer_sizes=(10, 2), solver=adam .........................
# [CV]  hidden_layer_sizes=(10, 2), solver=adam, score=1.000, total=   0.4s
# [CV] hidden_layer_sizes=(5, 3), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(5, 3), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(5, 3), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(5, 3), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(5, 3), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(5, 3), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(5, 3), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(5, 3), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(5, 3), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(5, 3), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(5, 3), solver=adam ..........................
# [CV]  hidden_layer_sizes=(5, 3), solver=adam, score=1.000, total=   0.4s
# [CV] hidden_layer_sizes=(5, 3), solver=adam ..........................
# [CV]  hidden_layer_sizes=(5, 3), solver=adam, score=1.000, total=   0.4s
# [CV] hidden_layer_sizes=(5, 3), solver=adam ..........................
# [CV]  hidden_layer_sizes=(5, 3), solver=adam, score=1.000, total=   0.3s
# [CV] hidden_layer_sizes=(5, 3), solver=adam ..........................
# [CV]  hidden_layer_sizes=(5, 3), solver=adam, score=1.000, total=   0.4s
# [CV] hidden_layer_sizes=(5, 3), solver=adam ..........................
# [CV]  hidden_layer_sizes=(5, 3), solver=adam, score=1.000, total=   0.5s
# [CV] hidden_layer_sizes=(8, 3), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(8, 3), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(8, 3), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(8, 3), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(8, 3), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(8, 3), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(8, 3), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(8, 3), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(8, 3), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(8, 3), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(8, 3), solver=adam ..........................
# [CV]  hidden_layer_sizes=(8, 3), solver=adam, score=1.000, total=   0.7s
# [CV] hidden_layer_sizes=(8, 3), solver=adam ..........................
# [CV]  hidden_layer_sizes=(8, 3), solver=adam, score=1.000, total=   3.7s
# [CV] hidden_layer_sizes=(8, 3), solver=adam ..........................
# [CV]  hidden_layer_sizes=(8, 3), solver=adam, score=1.000, total=   0.3s
# [CV] hidden_layer_sizes=(8, 3), solver=adam ..........................
# [CV]  hidden_layer_sizes=(8, 3), solver=adam, score=1.000, total=   0.4s
# [CV] hidden_layer_sizes=(8, 3), solver=adam ..........................
# [CV]  hidden_layer_sizes=(8, 3), solver=adam, score=1.000, total=   0.3s
# [CV] hidden_layer_sizes=(12, 3), solver=lbfgs ........................
# [CV]  hidden_layer_sizes=(12, 3), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(12, 3), solver=lbfgs ........................
# [CV]  hidden_layer_sizes=(12, 3), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(12, 3), solver=lbfgs ........................
# [CV]  hidden_layer_sizes=(12, 3), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(12, 3), solver=lbfgs ........................
# [CV]  hidden_layer_sizes=(12, 3), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(12, 3), solver=lbfgs ........................
# [CV]  hidden_layer_sizes=(12, 3), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(12, 3), solver=adam .........................
# [CV]  hidden_layer_sizes=(12, 3), solver=adam, score=1.000, total=   0.4s
# [CV] hidden_layer_sizes=(12, 3), solver=adam .........................
# [CV]  hidden_layer_sizes=(12, 3), solver=adam, score=1.000, total=   3.3s
# [CV] hidden_layer_sizes=(12, 3), solver=adam .........................
# [CV]  hidden_layer_sizes=(12, 3), solver=adam, score=1.000, total=   0.3s
# [CV] hidden_layer_sizes=(12, 3), solver=adam .........................
# [CV]  hidden_layer_sizes=(12, 3), solver=adam, score=1.000, total=   0.5s
# [CV] hidden_layer_sizes=(12, 3), solver=adam .........................
# [CV]  hidden_layer_sizes=(12, 3), solver=adam, score=1.000, total=   0.6s
# [CV] hidden_layer_sizes=(7, 4), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(7, 4), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(7, 4), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(7, 4), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(7, 4), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(7, 4), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(7, 4), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(7, 4), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(7, 4), solver=lbfgs .........................
# [CV]  hidden_layer_sizes=(7, 4), solver=lbfgs, score=1.000, total=   0.0s
# [CV] hidden_layer_sizes=(7, 4), solver=adam ..........................
# [CV]  hidden_layer_sizes=(7, 4), solver=adam, score=1.000, total=   0.3s
# [CV] hidden_layer_sizes=(7, 4), solver=adam ..........................
# [CV]  hidden_layer_sizes=(7, 4), solver=adam, score=1.000, total=   0.5s
# [CV] hidden_layer_sizes=(7, 4), solver=adam ..........................
# [CV]  hidden_layer_sizes=(7, 4), solver=adam, score=1.000, total=   0.3s
# [CV] hidden_layer_sizes=(7, 4), solver=adam ..........................
# [CV]  hidden_layer_sizes=(7, 4), solver=adam, score=1.000, total=   0.4s
# [CV] hidden_layer_sizes=(7, 4), solver=adam ..........................
# [CV]  hidden_layer_sizes=(7, 4), solver=adam, score=1.000, total=   0.5s
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed:   26.3s finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=MLPClassifier(activation='relu', alpha=1e-05,
#                                      batch_size='auto', beta_1=0.9,
#                                      beta_2=0.999, early_stopping=False,
#                                      epsilon=1e-08, hidden_layer_sizes=(100,),
#                                      learning_rate='constant',
#                                      learning_rate_init=0.001, max_fun=15000,
#                                      max_iter=3000, momentum=0.9,
#                                      n_iter_no_change=10,
#                                      nesterovs_momentum=True, power_t=0.5,
#                                      random_state=None, shuffle=True,
#                                      solver='adam', tol=0.0001,
#                                      validation_fraction=0.1, verbose=False,
#                                      warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid=[{'hidden_layer_sizes': [(5, 2), (8, 2), (10, 2),
#                                                  (5, 3), (8, 3), (12, 3),
#                                                  (7, 4)],
#                           'solver': ['lbfgs', 'adam']}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=4)

# %%
grid.best_params_
# Out:
# {'hidden_layer_sizes': (5, 2), 'solver': 'lbfgs'}

# %%
NN = MLPClassifier(solver='lbfgs', alpha=1e-5,
                     hidden_layer_sizes=(5,2), random_state=1,max_iter=3000)
NN.fit(train_split.iloc[:,:-1], train_split.label_class)
print('the accucary of the Neuro Network  {:.2%}'.format(NN.score(test_split.iloc[:,:-1],test_split.label_class)))
# Out:
# the accucary of the Neuro Network  81.46%

# %% [markdown]
# ### COMMENT:
# #### with the grid search on the optimizer and hidden_layer shape, the accuracy acctually get up a bit, as the options of hidden lays size are not much

# %% [markdown]
# ### 5. RandomForest Method

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
param_grid = [{'max_depth': [2,4,6,8,10,12,14,16],'min_samples_split':[2,4,6,8,10],'min_samples_leaf':[1,3,5,7,9]}]
grid = GridSearchCV(RandomForestClassifier(), param_grid, refit=True, verbose=4)
grid.fit(train_split.iloc[:,:-1], train_split.label_class,sample_weight=train_split_weight)
grid.best_params_
#grid_pred = grid.predict(X_test)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=2 ............
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=2, score=0.766, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=2 ............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=2, score=0.757, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=2 ............
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.5s remaining:    0.0s
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=2, score=0.775, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=2 ............
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.7s remaining:    0.0s
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=2, score=0.767, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=2, score=0.758, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=4, score=0.755, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=4, score=0.763, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=4, score=0.769, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=4, score=0.769, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=4, score=0.762, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=6, score=0.769, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=6, score=0.762, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=6, score=0.754, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=6, score=0.753, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=6, score=0.764, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=8, score=0.776, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=8, score=0.771, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=8, score=0.768, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=8, score=0.763, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=8, score=0.776, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=10, score=0.762, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=10, score=0.771, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=10, score=0.754, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=10, score=0.767, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=1, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=1, min_samples_split=10, score=0.762, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=2, score=0.765, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=2, score=0.766, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=2, score=0.767, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=2, score=0.767, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=2, score=0.762, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=4, score=0.762, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=4, score=0.772, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=4, score=0.779, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=4, score=0.762, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=4, score=0.754, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=6, score=0.765, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=6, score=0.768, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=6, score=0.766, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=6, score=0.763, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=6, score=0.765, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=8, score=0.767, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=8, score=0.773, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=8, score=0.752, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=8, score=0.749, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=8, score=0.762, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=10, score=0.767, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=10, score=0.776, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=10, score=0.767, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=10, score=0.773, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=3, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=3, min_samples_split=10, score=0.761, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=2, score=0.775, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=2, score=0.773, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=2, score=0.769, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=2, score=0.759, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=2, score=0.761, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=4, score=0.755, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=4, score=0.753, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=4, score=0.774, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=4, score=0.755, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=4, score=0.760, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=6, score=0.759, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=6, score=0.763, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=6, score=0.772, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=6, score=0.747, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=6, score=0.760, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=8, score=0.757, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=8, score=0.782, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=8, score=0.773, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=8, score=0.763, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=8, score=0.755, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=10, score=0.769, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=10, score=0.771, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=10, score=0.772, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=10, score=0.769, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=5, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=5, min_samples_split=10, score=0.755, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=2, score=0.753, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=2, score=0.769, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=2, score=0.776, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=2, score=0.763, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=2, score=0.760, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=4, score=0.763, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=4, score=0.763, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=4, score=0.762, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=4, score=0.763, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=4, score=0.758, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=6, score=0.762, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=6, score=0.782, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=6, score=0.782, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=6, score=0.744, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=6, score=0.759, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=8, score=0.775, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=8, score=0.766, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=8, score=0.775, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=8, score=0.763, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=8, score=0.767, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=10, score=0.770, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=10, score=0.772, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=10, score=0.773, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=10, score=0.770, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=7, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=7, min_samples_split=10, score=0.766, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=2, score=0.772, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=2, score=0.762, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=2, score=0.775, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=2, score=0.781, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=2 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=2, score=0.773, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=4, score=0.768, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=4, score=0.769, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=4, score=0.756, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=4, score=0.773, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=4 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=4, score=0.759, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=6, score=0.757, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=6, score=0.763, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=6, score=0.771, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=6, score=0.750, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=6 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=6, score=0.760, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=8, score=0.766, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=8, score=0.761, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=8, score=0.765, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=8, score=0.752, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=8 ............
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=8, score=0.768, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=10, score=0.767, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=10, score=0.776, total=   0.2s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=10, score=0.776, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=10, score=0.764, total=   0.3s
# [CV] max_depth=2, min_samples_leaf=9, min_samples_split=10 ...........
# [CV]  max_depth=2, min_samples_leaf=9, min_samples_split=10, score=0.752, total=   0.2s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=2, score=0.789, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=2, score=0.795, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=2, score=0.803, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=2, score=0.798, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=2, score=0.795, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=4, score=0.794, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=4, score=0.794, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=4, score=0.800, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=4, score=0.802, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=4, score=0.797, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.790, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.792, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.802, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.800, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=6, score=0.798, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=8, score=0.790, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=8, score=0.798, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=8, score=0.805, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=8, score=0.800, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=8, score=0.798, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=10, score=0.797, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=10, score=0.797, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=10, score=0.806, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=10, score=0.800, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=1, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=1, min_samples_split=10, score=0.795, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=2, score=0.794, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=2, score=0.797, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=2, score=0.800, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=2, score=0.799, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=2, score=0.802, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=4, score=0.794, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=4, score=0.793, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=4, score=0.802, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=4, score=0.798, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=4, score=0.799, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=6, score=0.791, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=6, score=0.793, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=6, score=0.800, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=6, score=0.797, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=6, score=0.800, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=8, score=0.801, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=8, score=0.795, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=8, score=0.800, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=8, score=0.801, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=8, score=0.796, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=10, score=0.791, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=10, score=0.801, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=10, score=0.804, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=10, score=0.798, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=3, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=3, min_samples_split=10, score=0.799, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=2, score=0.790, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=2, score=0.795, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=2, score=0.807, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=2, score=0.799, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=2, score=0.797, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=4, score=0.794, total=   0.2s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=4, score=0.799, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=4, score=0.801, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=4, score=0.804, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=4, score=0.803, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=6, score=0.789, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=6, score=0.795, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=6, score=0.802, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=6, score=0.798, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=6, score=0.799, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=8, score=0.789, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=8, score=0.796, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=8, score=0.801, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=8, score=0.799, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=8, score=0.799, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=10, score=0.790, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=10, score=0.794, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=10, score=0.802, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=10, score=0.801, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=5, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=5, min_samples_split=10, score=0.797, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=2, score=0.790, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=2, score=0.793, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=2, score=0.802, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=2, score=0.799, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=2, score=0.799, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=4, score=0.791, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=4, score=0.794, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=4, score=0.805, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=4, score=0.797, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=4, score=0.798, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=6, score=0.789, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=6, score=0.795, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=6, score=0.802, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=6, score=0.798, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=6, score=0.798, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=8, score=0.790, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=8, score=0.796, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=8, score=0.802, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=8, score=0.798, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=8, score=0.802, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=10, score=0.792, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=10, score=0.792, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=10, score=0.811, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=10, score=0.798, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=7, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=7, min_samples_split=10, score=0.799, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=2, score=0.789, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=2, score=0.791, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=2, score=0.804, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=2, score=0.798, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=2 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=2, score=0.801, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=4, score=0.789, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=4, score=0.796, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=4, score=0.806, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=4, score=0.799, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=4 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=4, score=0.798, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=6, score=0.793, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=6, score=0.796, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=6, score=0.806, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=6, score=0.797, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=6 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=6, score=0.798, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=8, score=0.790, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=8, score=0.796, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=8, score=0.804, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=8, score=0.798, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=8 ............
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=8, score=0.795, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=10, score=0.789, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=10, score=0.799, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=10, score=0.805, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=10, score=0.800, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=9, min_samples_split=10 ...........
# [CV]  max_depth=4, min_samples_leaf=9, min_samples_split=10, score=0.802, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=2 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.804, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=2 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.805, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=2 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.815, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=2 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.809, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=2 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=2, score=0.808, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=4 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.802, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=4 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.804, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=4 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.815, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=4 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.808, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=4 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=4, score=0.806, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=6 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.801, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=6 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.807, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=6 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.815, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=6 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.809, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=6 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=6, score=0.806, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=8 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=8, score=0.802, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=8 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=8, score=0.805, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=8 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=8, score=0.809, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=8 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=8, score=0.810, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=8 ............
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=8, score=0.805, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=10, score=0.805, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=10, score=0.806, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=10, score=0.815, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=10, score=0.808, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=1, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=1, min_samples_split=10, score=0.807, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=2, score=0.804, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=2, score=0.805, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=2, score=0.807, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=2, score=0.813, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=2 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=2, score=0.807, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=4 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=4, score=0.799, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=4 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=4, score=0.806, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=4 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=4, score=0.816, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=4 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=4, score=0.810, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=4 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=4, score=0.807, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=6 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=6, score=0.801, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=6 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=6, score=0.804, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=6 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=6, score=0.815, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=6 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=6, score=0.811, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=6 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=6, score=0.806, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=8 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=8, score=0.804, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=8 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=8, score=0.806, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=8 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=8, score=0.815, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=8 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=8, score=0.810, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=8 ............
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=8, score=0.806, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=10, score=0.803, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=10, score=0.804, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=10, score=0.815, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=10, score=0.811, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=3, min_samples_split=10 ...........
# [CV]  max_depth=6, min_samples_leaf=3, min_samples_split=10, score=0.808, total=   0.3s
# [CV] max_depth=6, min_samples_leaf=5, min_samples_split=2 ............
# ...
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=2, score=0.807, total=   0.5s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=2, score=0.807, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=2, score=0.810, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=2, score=0.815, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=2, score=0.805, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=4, score=0.807, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=4, score=0.809, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=4, score=0.809, total=   0.5s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=4, score=0.813, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=4, score=0.808, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=6, score=0.803, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=6, score=0.810, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=6, score=0.807, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=6, score=0.813, total=   0.5s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=6, score=0.807, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=8, score=0.804, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=8, score=0.810, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=8, score=0.810, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=8, score=0.814, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=8, score=0.806, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=10, score=0.806, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=10, score=0.808, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=10, score=0.810, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=10, score=0.812, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=3, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=3, min_samples_split=10, score=0.808, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=2, score=0.805, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=2, score=0.808, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=2, score=0.810, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=2, score=0.817, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=2, score=0.805, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=4, score=0.806, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=4, score=0.810, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=4, score=0.810, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=4, score=0.816, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=4, score=0.806, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=6, score=0.806, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=6, score=0.808, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=6, score=0.811, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=6, score=0.813, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=6, score=0.804, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=8, score=0.805, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=8, score=0.810, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=8, score=0.810, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=8, score=0.815, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=8, score=0.807, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=10, score=0.806, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=10, score=0.810, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=10, score=0.811, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=10, score=0.816, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=5, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=5, min_samples_split=10, score=0.806, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=2, score=0.806, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=2, score=0.807, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=2, score=0.811, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=2, score=0.815, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=2, score=0.804, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=4, score=0.806, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=4, score=0.808, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=4, score=0.810, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=4, score=0.816, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=4, score=0.806, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=6, score=0.806, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=6, score=0.810, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=6, score=0.810, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=6, score=0.815, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=6, score=0.805, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=8, score=0.807, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=8, score=0.808, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=8, score=0.811, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=8, score=0.815, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=8, score=0.805, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=10, score=0.806, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=10, score=0.809, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=10, score=0.808, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=10, score=0.816, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=7, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=7, min_samples_split=10, score=0.809, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=2, score=0.804, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=2, score=0.809, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=2, score=0.809, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=2, score=0.814, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=2 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=2, score=0.805, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=4, score=0.804, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=4, score=0.809, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=4, score=0.809, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=4, score=0.813, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=4 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=4, score=0.808, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=6, score=0.805, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=6, score=0.809, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=6, score=0.811, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=6, score=0.814, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=6 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=6, score=0.808, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=8, score=0.804, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=8, score=0.811, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=8, score=0.811, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=8, score=0.815, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=8 ...........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=8, score=0.805, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=10, score=0.804, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=10, score=0.810, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=10, score=0.812, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=10, score=0.816, total=   0.4s
# [CV] max_depth=16, min_samples_leaf=9, min_samples_split=10 ..........
# [CV]  max_depth=16, min_samples_leaf=9, min_samples_split=10, score=0.806, total=   0.4s
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:  5.7min finished
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 8}

# %%
grid.best_params_
# Out:
# {'max_depth': 12, 'min_samples_leaf': 9, 'min_samples_split': 6}

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=12,min_samples_leaf=9,min_samples_split=6)
clf.fit(train_split.iloc[:,:-1], train_split.label_class,sample_weight=train_split_weight)
clf.score(test_split.iloc[:,:-1],test_split.label_class,sample_weight=test_split_weight)
# Out:
# 0.8177500750743952

# %%
save_acc_and_roc(clf,'RFT')

# %%
confusion_matrix_plot(clf,'RFT')
# Out:
# RFT Confusion matrix, without normalization
# [[3110  662]
#  [ 747 3025]]
# RFT Normalized confusion matrix
# [[0.82449629 0.17550371]
#  [0.19803818 0.80196182]]

# %%
print(classification_report(test_split.label_class,NN.predict(test_split.iloc[:,:-1]), target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.80      0.84      0.82      3772
#      class 1       0.83      0.79      0.81      3772
#
#     accuracy                           0.81      7544
#    macro avg       0.82      0.81      0.81      7544
# weighted avg       0.82      0.81      0.81      7544

# %%
AUROC_plot('RFT')

# %% [markdown]
# ### COMMENT: so far the Radom Forest and SVM behaves the best, round 82% of accuracy, but still similar to others

# %% [markdown]
# ## Summary

# %% [markdown]
# ### This study with the prediction of income. The training data is higly imbalanced, as to be consistant with the results from others, no test data is used in the training. In general 5 models are use, the SVM, Logistic regression, Navie bayes, Neuro Networks, Random Forest

# %% [markdown]
# ### The behaviour of the above methods are similar, in both accuracy and AUROC. During the training, the balance is considered between the two classes, as the training sample, after adjust hold similar number of >50K and <=50K events

# %%
Lable_method=[]
value_acc=[]
for i,j in accuracy.items():
    Lable_method.append(i)
    value_acc.append(j)

# %%
ax = sns.barplot(x=Lable_method, y=value_acc)

# %% [markdown]
# ### while the AUROC is 90%
